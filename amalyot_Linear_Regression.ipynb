# %% [markdown]
# <a href="https://colab.research.google.com/github/javmohir/Regression/blob/main/amalyot_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/reklama_sales.csv')
df.head(20)
# Out:
#        TV  Radio  Newspaper  Sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3   12.0
# 3   151.5   41.3       58.5   16.5
# 4   180.8   10.8       58.4   17.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   15.6
# 10   66.1    5.8       24.2   12.6
# 11  214.7   24.0        4.0   17.4
# 12   23.8   35.1       65.9    9.2
# 13   97.5    7.6        7.2   13.7
# 14  204.1   32.9       46.0   19.0
# 15  195.4   47.7       52.9   22.4
# 16   67.8   36.6      114.0   12.5
# 17  281.4   39.6       55.8   24.4
# 18   69.2   20.5       18.3   11.3
# 19  147.3   23.9       19.1   14.6

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='TV', y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Radio', y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Newspaper', y='Sales')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df, x = 'TV', y = 'Sales', line_kws={'color':'red'})
plt.show()

# %%
reklam = df['TV']

# %%
df.shape
# Out:
# (200, 4)

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.10, random_state=42)

# %%
from sklearn import linear_model
LR_model = linear_model.LinearRegression()

x_train = np.asanyarray(train_set[['TV']])
y_train = np.asanyarray(train_set[['Sales']])

# Modelni tarbiyalaymiz (train)
LR_model.fit(x_train, y_train)
#theta1 va theta0 koeefisentlarni ajratib olamiz
theta1 = LR_model.coef_[0][0]
theta0 = LR_model.intercept_[0]
print(f'{theta1=}')
print(f'{theta0=}')
# Out:
# theta1=0.05513263076693964
# theta0=7.044916461655207

# %% [markdown]
# θ 0​va � 1 θ 1​qiymatlari yordamida to'g'ri chiziq chizamiz

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='TV', y='Sales')
plt.plot(x_train, theta1*x_train + theta0, '-r')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# Modelni baholaymiz

# %%
x_test = np.asanyarray(test_set[['TV']])
y_test = np.asanyarray(test_set[['Sales']])

# %%
y_predict = LR_model.predict(x_test)
y_predict
# Out:
# array([[16.04807507],
#        [17.81783251],
#        [23.19326401],
#        [ 7.68996824],
#        [19.19063502],
#        [11.18537703],
#        [18.99767081],
#        [ 9.801548  ],
#        [19.30641354],
#        [16.69864011],
#        [ 8.78159433],
#        [10.14337031],
#        [19.97351838],
#        [ 7.34263267],
#        [14.73591845],
#        [16.42849022],
#        [ 7.44738467],
#        [17.9391243 ],
#        [11.19640356],
#        [20.13340301]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

MAE = mean_absolute_error(y_test, y_predict)
RMSE = np.sqrt(mean_squared_error(y_test, y_predict))
print(f'{MAE=}')
print(f'{RMSE=}')
# Out:
# MAE=2.037955356968121
# RMSE=2.5103822386472214

# %%
y_test
# Out:
# array([[16.9],
#        [22.4],
#        [21.4],
#        [ 7.3],
#        [24.7],
#        [12.6],
#        [22.3],
#        [ 8.4],
#        [16.5],
#        [16.1],
#        [11. ],
#        [ 8.7],
#        [16.9],
#        [ 5.3],
#        [10.3],
#        [16.7],
#        [ 5.5],
#        [16.6],
#        [11.3],
#        [18.9]])
